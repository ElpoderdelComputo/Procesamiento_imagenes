# %% [markdown]
# <a href="https://colab.research.google.com/github/ElpoderdelComputo/Procesamiento_imagenes/blob/main/VA_edimensionar_rotar_recortar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Visión Artificial**
#
# “Operaciones básicas en OpenCV: redimensionar, rotar, recortar y convertir a escala de grises”
#
# YouTube: El poder del Cómputo

# %%
# 🧠 Procesamiento de imágenes con OpenCV
# 🎬 Operaciones básicas: redimensionar, rotar, recortar y convertir a escala de grises

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# Leer imagen (BGR)
imagen = cv2.imread('/content/flor.png')

# %%
# convertir la imgen bgr a RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen_rgb)
plt.title('Imagen RGB')
plt.axis('off')
plt.show()

# %%
# mostrar las propiedades de la imagen
print('Dimensiones de la imagen:', imagen.shape)
print('Tipo de datos de la imagen:', imagen.dtype)
# Out:
# Dimensiones de la imagen: (480, 817, 3)
# Tipo de datos de la imagen: uint8

# %%
# Redimensionar a un tamaño fijo
# imagen_redimensionada = cv2.resize(imagen_rgb, (tamaño_x, tamaño_y))
imagen_redimensionada = cv2.resize(imagen_rgb, (100, 100))

fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(imagen_rgb);
axs[0].set_title('original (480, 817, 3)')
axs[1].imshow(imagen_redimensionada);
axs[1].set_title('Redimensionada')
# Out:
# Text(0.5, 1.0, 'Redimensionada')

# %%
# Redimensionar por factor
#peq_50 = cv2.resize(imagen_rgb, (x, y), factorX, factorY)
peq_50 = cv2.resize(imagen_rgb, (0, 0), fx=0.3, fy=0.3)
print('Tamaño: ', peq_50.shape)
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(imagen_rgb); axs[0].set_title('original')
axs[1].imshow(peq_50); axs[1].set_title('pequeño')
# Out:
# Tamaño:  (144, 245, 3)
# Text(0.5, 1.0, 'pequeño')

# %%
# Redimensionar a un tamaño fijo
redimensionada = cv2.resize(imagen_rgb, (400, 300))

# Redimensionar por factor
peq = cv2.resize(imagen_rgb, (0, 0), fx=0.5, fy=0.5)
grande = cv2.resize(imagen_rgb, (0, 0), fx=1.5, fy=1.5)

fig, axs = plt.subplots(1, 3, figsize=(12, 4))
axs[0].imshow(redimensionada); axs[0].set_title('400x300')
axs[1].imshow(peq); axs[1].set_title('Mitad del tamaño')
axs[2].imshow(grande); axs[2].set_title('1.5x más grande')
plt.show()

# %%
# rotacion
alto, ancho = imagen.shape[:2]
#centro = (ancho // 2, alto // 2)
centro = (0, 480)
angulo = 25

#matriz_rotacion = cv2.getRotationMatrix2D(centro, grados_a_rotar, nivel_zoom)
matriz_rotacion = cv2.getRotationMatrix2D(centro, angulo, 1.0)

rotada = cv2.warpAffine(imagen_rgb, matriz_rotacion, (ancho, alto))

fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(imagen_rgb); axs[0].set_title('Imagen original')
axs[1].imshow(rotada); axs[1].set_title('Imagen rotada')
plt.show()

# %%
# Recorte
#recorte = imagen_rgb[y1:y2, x1:x2]
#recorte = imagen_rgb[200:500, 300:700]
#recortar la primera flor:
recorte = imagen_rgb[150:450, 150:450]

fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(imagen_rgb); axs[0].set_title('Imagen original')
axs[1].imshow(recorte); axs[1].set_title('Imagen recortada')
plt.show()

# %%
# Convertir a escala de grises
gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(imagen_rgb); axs[0].set_title('Imagen original')
axs[1].imshow(gris, cmap='gray'); axs[1].set_title('Escala de grises')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0,0].imshow(imagen_rgb); axs[0,0].set_title('Original')
axs[0,1].imshow(redimensionada); axs[0,1].set_title('Redimensionada')
axs[1,0].imshow(rotada); axs[1,0].set_title('Rotada')
axs[1,1].imshow(gris, cmap='gray'); axs[1,1].set_title('Grises')

plt.tight_layout()
plt.show()
